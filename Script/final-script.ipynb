# %%
# ==============================================================================
# 1. INSTALL AND IMPORT PACKAGES
# ==============================================================================
# Install the required spacy model
# !python -m spacy download en_core_web_sm

# Import necessary libraries
import pandas as pd
import re
from collections import Counter, defaultdict
import spacy
from spacy.tokens import Doc
from itertools import product
import time
import tracemalloc
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# ==============================================================================
# 2. DEFINE DATA NORMALIZATION CLASS
# ==============================================================================
class NormalizedInput:
    """
    Reads and processes the input CSV to extract and count words from a text column.
    """
    def __init__(self, csv_path, text_column):
        self.csv_path = csv_path
        self.text_column = text_column
        self.df = None
        self.processed_df = None

    def read_csv(self):
        print("[NormalizedInput] Reading CSV file:", self.csv_path)
        self.df = pd.read_csv(self.csv_path)
        print("[NormalizedInput] CSV loaded. Shape:", self.df.shape)

    def normalize_text(self, text):
        # Finds all alphabetic words in a lowercased string
        words = re.findall(r'\b[a-zA-Z]+\b', str(text).lower())
        return words

    def count_words(self, words):
        return dict(Counter(words))

    def process(self):
        tracemalloc.start()
        start_time = time.time()
        print("[NormalizedInput] Starting processing of DataFrame.")
        if self.df is None:
            self.read_csv()
        processed_dict = {}
        for idx, row in self.df.iterrows():
            words = self.normalize_text(row[self.text_column])
            word_count = self.count_words(words)
            row_id = row['id'] if 'id' in row else idx
            processed_dict[row_id] = word_count
        self.processed_df = processed_dict
        end_time = time.time()
        current, peak = tracemalloc.get_traced_memory()
        tracemalloc.stop()
        print(f"Time taken: {end_time - start_time:.4f} seconds")
        print(f"Current memory usage: {current / 10**6:.4f} MB; Peak: {peak / 10**6:.4f} MB")

    def get_processed_dictionary(self):
        if self.processed_df is None:
            self.process()
        return self.processed_df

# ==============================================================================
# 3. DEFINE TEMPLATE-BASED SENTENCE GENERATION CLASS
# ==============================================================================
# Define Part-of-Speech (POS) templates from longest to shortest
TEMPLATES = [
    ['determiner', 'adjective', 'noun', 'verb', 'preposition', 'determiner', 'noun'],
    ['determiner', 'adjective', 'noun'],
    ['determiner', 'noun', 'verb', 'noun'],
    ['noun', 'verb', 'noun'],
    ['noun', 'verb', 'preposition', 'noun'],
    ['noun', 'verb', 'determiner', 'noun'],
    ['noun', 'verb', 'adjective', 'noun'],
    ['noun', 'verb', 'conjunction', 'noun'],
    ['noun', 'verb'],
    ['noun', 'noun'],
    ['determiner', 'noun'],
]

class TemplatesGeneration:
    """
    Generates sentences by filling POS templates with words from the input text.
    """
    def __init__(self, normalized_input):
        self.normalized_input = normalized_input
        self.processed_dict = self.normalized_input.get_processed_dictionary()
        self.all_sentences = []
        self.nlp = spacy.load("en_core_web_sm")

    def classify_words_in_row(self, row_id, words):
        doc = Doc(self.nlp.vocab, words=words)
        for name, proc in self.nlp.pipeline:
            doc = proc(doc)
        results = []
        for token in doc:
            pos = token.pos_.lower()
            results.append({'id': row_id, 'word': token.text, 'pos': pos})
        return results

    def group_words_by_pos_with_duplicates(self, classified_words):
        grouped = defaultdict(list)
        word_pos_count = defaultdict(int)
        for item in classified_words:
            pos = item['pos']
            grouped[pos].append((item['word'], word_pos_count[(item['word'], pos)]))
            word_pos_count[(item['word'], pos)] += 1
        return grouped

    def generate_sentences_for_template_with_duplicates(self, word_pos_dict, template):
        if not all(pos in word_pos_dict and word_pos_dict[pos] for pos in template):
            return []
        slot_word_occurrences = [word_pos_dict[pos] for pos in template]
        all_assignments = product(*slot_word_occurrences)
        sentences = set()
        for assignment in all_assignments:
            if len(set(assignment)) == len(assignment):
                sentence = ' '.join(word for word, idx in assignment)
                sentences.add(sentence)
        return list(sentences)

    def get_largest_template(self, word_pos_dict):
        for template in TEMPLATES:
            if all(pos in word_pos_dict and word_pos_dict[pos] for pos in template):
                return template
        return None

    def get_unused_words(self, all_words, used_words):
        return set(all_words) - set(used_words)

    def generate(self, output_path):
        print("[TemplatesGeneration] Starting sentence generation.")
        for row_id, word_counts in self.processed_dict.items():
            words = []
            for word, count in word_counts.items():
                words.extend([word] * count)
            classified = self.classify_words_in_row(row_id, words)
            word_pos_dict = self.group_words_by_pos_with_duplicates(classified)
            all_words = [item['word'] for item in classified]
            used_words = set()
            generated_sentences = []

            largest_template = self.get_largest_template({k: [w for w, i in v] for k, v in word_pos_dict.items()})
            if largest_template:
                generated_sentences = self.generate_sentences_for_template_with_duplicates(word_pos_dict, largest_template)
                for sentence in generated_sentences:
                    used_words.update(sentence.split())

            unused_words = self.get_unused_words(all_words, used_words)
            if unused_words:
                unused_word_pos_dict = {cat: [wi for wi in word_pos_dict[cat] if wi[0] in unused_words] for cat in word_pos_dict}
                for template in TEMPLATES:
                    fallback_sentences = self.generate_sentences_for_template_with_duplicates(unused_word_pos_dict, template)
                    for sentence in fallback_sentences:
                        words_in_sentence = set(sentence.split())
                        if words_in_sentence & unused_words:
                            generated_sentences.append(sentence)
                            used_words.update(words_in_sentence)
                    unused_words = self.get_unused_words(all_words, used_words)
                    if not unused_words:
                        break

            for sentence in generated_sentences:
                self.all_sentences.append({'id': row_id, 'sentence': sentence})

        pd.DataFrame(self.all_sentences).to_csv(output_path, index=False)
        print(f"[TemplatesGeneration] All generated sentences saved to {output_path}")

# ==============================================================================
# 4. DEFINE FINAL PASSAGE GENERATION CLASS
# ==============================================================================
class SentencesGeneration:
    """
    Combines generated sentences and appends missing words based on perplexity
    using a causal language model (Gemma 2).
    """
    def __init__(self, sentence_csv_path, processed_dict, model, tokenizer):
        self.sentence_csv_path = sentence_csv_path
        self.processed_dict = processed_dict
        self.sent_df = pd.read_csv(sentence_csv_path)
        self.final_sentences = []
        self.model = model
        self.tokenizer = tokenizer

    def get_perplexity_with_gemma2(self, text):
        """
        Computes perplexity for a single text string using the provided model.
        """
        inputs = self.tokenizer(text, return_tensors="pt").to(self.model.device)
        with torch.no_grad():
            outputs = self.model(**inputs, labels=inputs["input_ids"])
            loss = outputs.loss
        perplexity = torch.exp(loss).item()
        return perplexity

    def combine_sentences_per_row(self):
        print("[SentencesGeneration] Starting final passage combination.")
        for row_id, word_count_dict in self.processed_dict.items():
            original_bag = []
            for word, count in word_count_dict.items():
                original_bag.extend([word] * count)
            original_counter = Counter(original_bag)
            n_words = len(original_bag)

            row_sentences = self.sent_df[self.sent_df['id'] == row_id]['sentence'].tolist()
            sentence_word_lists = [s.split() for s in row_sentences]

            used_counter = Counter()
            selected_sentences = []
            # Greedily select longest sentences first that don't overuse words
            for words, sent in sorted(zip(sentence_word_lists, row_sentences), key=lambda x: -len(x[0])):
                temp_counter = Counter(words)
                if all(used_counter[w] + temp_counter[w] <= original_counter[w] for w in temp_counter):
                    selected_sentences.append(sent)
                    used_counter += temp_counter
                if sum(used_counter.values()) == n_words:
                    break

            final_counter = Counter()
            for sent in selected_sentences:
                final_counter += Counter(sent.split())

            missing_words = list((original_counter - final_counter).elements())
            current_combined_sentence = " ".join(selected_sentences)

            # Append missing words one by one, choosing the one that minimizes perplexity
            while missing_words:
                candidates = []
                for word in set(missing_words):
                    trial_sentence = current_combined_sentence + " " + word
                    perplexity = self.get_perplexity_with_gemma2(trial_sentence)
                    
                    # <<< PRINT STATEMENT ADDED HERE >>>
                    print(f"  > Evaluating word '{word}'. Perplexity: {perplexity:.4f}")
                    
                    candidates.append((word, perplexity))
                
                if not candidates: break # Break if no candidates found

                best_word, best_perplexity = min(candidates, key=lambda x: x[1])
                print(f"  >> Selected best word '{best_word}' with perplexity {best_perplexity:.4f}\n")
                current_combined_sentence += " " + best_word
                missing_words.remove(best_word)

            self.final_sentences.append({
                "id": row_id,
                "text": current_combined_sentence.strip() # Match submission format
            })

    def save(self, output_path):
        submission_df = pd.DataFrame(self.final_sentences)
        submission_df.to_csv(output_path, index=False)
        print("\nFinal Submission DataFrame:")
        print(submission_df)
        print(f"\n[SentencesGeneration] Final submission saved to {output_path}")

# ==============================================================================
# 5. MAIN EXECUTION SCRIPT
# ==============================================================================
if __name__ == '__main__':
    # --- Configuration ---
    INPUT_CSV_PATH = '/kaggle/input/santa-2024/sample_submission.csv'
    TEXT_COLUMN = 'text'
    MODEL_PATH = "/kaggle/input/gemma-2/transformers/gemma-2-2b/2/"
    TEMP_SENTENCES_PATH = '/kaggle/working/templates_generation.csv'
    FINAL_OUTPUT_PATH = '/kaggle/working/submission.csv'

    # --- Step 1: Load and process the initial data ---
    normalizer = NormalizedInput(csv_path=INPUT_CSV_PATH, text_column=TEXT_COLUMN)
    processed_word_dict = normalizer.get_processed_dictionary()

    # --- Step 2: Generate sentences from templates ---
    template_generator = TemplatesGeneration(normalized_input=normalizer)
    template_generator.generate(output_path=TEMP_SENTENCES_PATH)
    
    # --- Step 3: Load the Causal Language Model and Tokenizer ---
    # Set device
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"[Main] Using device: {device}")

    # Load tokenizer and model from the specified path
    tokenizer = AutoTokenizer.from_pretrained(MODEL_PATH)
    model = AutoModelForCausalLM.from_pretrained(MODEL_PATH).to(device)
    print("[Main] Model and tokenizer loaded successfully.")

    # --- Step 4: Combine sentences into final passages ---
    sentence_combiner = SentencesGeneration(
        sentence_csv_path=TEMP_SENTENCES_PATH,
        processed_dict=processed_word_dict,
        model=model,
        tokenizer=tokenizer
    )
    sentence_combiner.combine_sentences_per_row()
    
    # --- Step 5: Save the final submission file ---
    sentence_combiner.save(output_path=FINAL_OUTPUT_PATH)

    print("\n[Main] End-to-end process completed.")
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 40.9 MB/s eta 0:00:0000:0100:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# [NormalizedInput] Starting processing of DataFrame.
# [NormalizedInput] Reading CSV file: /kaggle/input/santa-2024/sample_submission.csv
# [NormalizedInput] CSV loaded. Shape: (6, 2)
# Time taken: 0.0294 seconds
# Current memory usage: 0.0876 MB; Peak: 0.8493 MB
# [TemplatesGeneration] Starting sentence generation.
# [TemplatesGeneration] All generated sentences saved to /kaggle/working/templates_generation.csv
# [Main] Using device: cpu
# 2025-07-12 04:12:07.433386: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752293527.681581      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752293527.748223      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# [Main] Model and tokenizer loaded successfully.
# [SentencesGeneration] Starting final passage combination.
#   > Evaluating word 'advent'. Perplexity: 58087.5430
#   > Evaluating word 'chimney'. Perplexity: 68447.8984
#   > Evaluating word 'gingerbread'. Perplexity: 49989.4727
#   > Evaluating word 'elf'. Perplexity: 50517.7031
#   > Evaluating word 'ornament'. Perplexity: 34703.8203
#   > Evaluating word 'mistletoe'. Perplexity: 22191.8340
#   >> Selected best word 'mistletoe' with perplexity 22191.8340
#
#   > Evaluating word 'advent'. Perplexity: 15899.4199
#   > Evaluating word 'chimney'. Perplexity: 15930.8535
#   > Evaluating word 'gingerbread'. Perplexity: 13274.8760
#   > Evaluating word 'elf'. Perplexity: 13280.6250
#   > Evaluating word 'ornament'. Perplexity: 12444.9180
#   >> Selected best word 'ornament' with perplexity 12444.9180
#
#   > Evaluating word 'elf'. Perplexity: 12189.0205
#   > Evaluating word 'advent'. Perplexity: 10238.0137
#   > Evaluating word 'gingerbread'. Perplexity: 10746.6318
#   > Evaluating word 'chimney'. Perplexity: 13463.4688
#   >> Selected best word 'advent' with perplexity 10238.0137
#
#   > Evaluating word 'elf'. Perplexity: 9902.4521
#   > Evaluating word 'chimney'. Perplexity: 11418.9990
#   > Evaluating word 'gingerbread'. Perplexity: 11124.0742
#   >> Selected best word 'elf' with perplexity 9902.4521
#
#   > Evaluating word 'gingerbread'. Perplexity: 7705.2002
#   > Evaluating word 'chimney'. Perplexity: 8818.9375
#   >> Selected best word 'gingerbread' with perplexity 7705.2002
#
#   > Evaluating word 'chimney'. Perplexity: 6951.5288
#   >> Selected best word 'chimney' with perplexity 6951.5288
#
#   > Evaluating word 'bake'. Perplexity: 459119.8125
#   > Evaluating word 'advent'. Perplexity: 300174.6250
#   > Evaluating word 'chimney'. Perplexity: 845733.6250
#   > Evaluating word 'the'. Perplexity: 41144.0273
#   > Evaluating word 'gingerbread'. Perplexity: 291873.0000
#   > Evaluating word 'elf'. Perplexity: 101663.0234
#   > Evaluating word 'laugh'. Perplexity: 570961.1250
#   > Evaluating word 'drive'. Perplexity: 125451.5078
#   > Evaluating word 'ornament'. Perplexity: 268228.2812
#   > Evaluating word 'fireplace'. Perplexity: 1015133.9375
#   > Evaluating word 'mistletoe'. Perplexity: 23063.0957
#   > Evaluating word 'jump'. Perplexity: 122384.3672
#   > Evaluating word 'night'. Perplexity: 77802.3281
#   > Evaluating word 'and'. Perplexity: 27656.7441
#   > Evaluating word 'family'. Perplexity: 339353.4375
#   > Evaluating word 'scrooge'. Perplexity: 15978.8594
#   > Evaluating word 'walk'. Perplexity: 69445.6797
#   >> Selected best word 'scrooge' with perplexity 15978.8594
#
#   > Evaluating word 'bake'. Perplexity: 38887.9023
#   > Evaluating word 'advent'. Perplexity: 23228.6465
#   > Evaluating word 'chimney'. Perplexity: 30124.7598
#   > Evaluating word 'the'. Perplexity: 7306.3608
#   > Evaluating word 'gingerbread'. Perplexity: 17057.7188
#   > Evaluating word 'elf'. Perplexity: 13588.1250
#   > Evaluating word 'laugh'. Perplexity: 15353.8721
#   > Evaluating word 'drive'. Perplexity: 18655.9512
#   > Evaluating word 'ornament'. Perplexity: 17235.5312
#   > Evaluating word 'fireplace'. Perplexity: 32340.3945
#   > Evaluating word 'mistletoe'. Perplexity: 5698.0410
#   > Evaluating word 'jump'. Perplexity: 14708.0107
#   > Evaluating word 'night'. Perplexity: 10467.0664
#   > Evaluating word 'and'. Perplexity: 6763.3394
#   > Evaluating word 'family'. Perplexity: 16539.1523
#   > Evaluating word 'walk'. Perplexity: 18634.5781
#   >> Selected best word 'mistletoe' with perplexity 5698.0410
#
#   > Evaluating word 'bake'. Perplexity: 8089.4946
#   > Evaluating word 'advent'. Perplexity: 6490.6079
#   > Evaluating word 'chimney'. Perplexity: 7024.8975
#   > Evaluating word 'the'. Perplexity: 3518.7434
#   > Evaluating word 'gingerbread'. Perplexity: 5262.3833
#   > Evaluating word 'elf'. Perplexity: 4384.0190
#   > Evaluating word 'laugh'. Perplexity: 6020.1792
#   > Evaluating word 'drive'. Perplexity: 6442.6772
#   > Evaluating word 'ornament'. Perplexity: 6077.7217
#   > Evaluating word 'fireplace'. Perplexity: 7841.8706
#   > Evaluating word 'jump'. Perplexity: 5712.3232
#   > Evaluating word 'night'. Perplexity: 4774.9829
#   > Evaluating word 'and'. Perplexity: 3145.9680
#   > Evaluating word 'family'. Perplexity: 5175.1045
#   > Evaluating word 'walk'. Perplexity: 6370.4604
#   >> Selected best word 'and' with perplexity 3145.9680
#
#   > Evaluating word 'bake'. Perplexity: 4222.0010
#   > Evaluating word 'advent'. Perplexity: 3976.6106
#   > Evaluating word 'chimney'. Perplexity: 3158.0520
#   > Evaluating word 'the'. Perplexity: 1933.3424
#   > Evaluating word 'gingerbread'. Perplexity: 2432.6379
#   > Evaluating word 'elf'. Perplexity: 2586.2878
#   > Evaluating word 'laugh'. Perplexity: 3526.2852
#   > Evaluating word 'drive'. Perplexity: 4736.1748
#   > Evaluating word 'ornament'. Perplexity: 3468.3191
#   > Evaluating word 'fireplace'. Perplexity: 3543.5588
#   > Evaluating word 'jump'. Perplexity: 3405.1824
#   > Evaluating word 'night'. Perplexity: 3149.1558
#   > Evaluating word 'family'. Perplexity: 3164.9775
#   > Evaluating word 'walk'. Perplexity: 3595.9309
#   >> Selected best word 'the' with perplexity 1933.3424
#
#   > Evaluating word 'bake'. Perplexity: 3567.1169
#   > Evaluating word 'advent'. Perplexity: 3142.7654
#   > Evaluating word 'chimney'. Perplexity: 1903.0593
#   > Evaluating word 'gingerbread'. Perplexity: 1735.7794
#   > Evaluating word 'elf'. Perplexity: 1475.2345
#   > Evaluating word 'laugh'. Perplexity: 3087.0059
#   > Evaluating word 'drive'. Perplexity: 3443.2063
#   > Evaluating word 'ornament'. Perplexity: 2523.2595
#   > Evaluating word 'fireplace'. Perplexity: 1868.1517
#   > Evaluating word 'jump'. Perplexity: 2993.2188
#   > Evaluating word 'night'. Perplexity: 1534.2930
#   > Evaluating word 'family'. Perplexity: 1712.9902
#   > Evaluating word 'walk'. Perplexity: 2483.1699
#   >> Selected best word 'elf' with perplexity 1475.2345
#
#   > Evaluating word 'bake'. Perplexity: 2026.6637
#   > Evaluating word 'advent'. Perplexity: 2410.2566
#   > Evaluating word 'chimney'. Perplexity: 1998.5482
#   > Evaluating word 'gingerbread'. Perplexity: 1962.4758
#   > Evaluating word 'laugh'. Perplexity: 1735.1613
#   > Evaluating word 'drive'. Perplexity: 2480.1218
#   > Evaluating word 'ornament'. Perplexity: 2007.0688
#   > Evaluating word 'fireplace'. Perplexity: 2312.0881
#   > Evaluating word 'jump'. Perplexity: 1844.5972
#   > Evaluating word 'night'. Perplexity: 2009.6172
#   > Evaluating word 'family'. Perplexity: 1671.2333
#   > Evaluating word 'walk'. Perplexity: 1811.7629
#   >> Selected best word 'family' with perplexity 1671.2333
#
#   > Evaluating word 'bake'. Perplexity: 2204.6567
#   > Evaluating word 'advent'. Perplexity: 2239.5544
#   > Evaluating word 'chimney'. Perplexity: 2025.4879
#   > Evaluating word 'gingerbread'. Perplexity: 1631.3076
#   > Evaluating word 'laugh'. Perplexity: 2013.4722
#   > Evaluating word 'drive'. Perplexity: 2219.9729
#   > Evaluating word 'ornament'. Perplexity: 2066.6174
#   > Evaluating word 'fireplace'. Perplexity: 2017.5278
#   > Evaluating word 'jump'. Perplexity: 2041.9933
#   > Evaluating word 'night'. Perplexity: 1740.2638
#   > Evaluating word 'walk'. Perplexity: 2007.6106
#   >> Selected best word 'gingerbread' with perplexity 1631.3076
#
#   > Evaluating word 'bake'. Perplexity: 1735.5079
#   > Evaluating word 'advent'. Perplexity: 2098.4492
#   > Evaluating word 'chimney'. Perplexity: 2025.9062
#   > Evaluating word 'laugh'. Perplexity: 2263.0034
#   > Evaluating word 'drive'. Perplexity: 2443.1628
#   > Evaluating word 'ornament'. Perplexity: 2108.1968
#   > Evaluating word 'fireplace'. Perplexity: 2304.6714
#   > Evaluating word 'jump'. Perplexity: 2467.0493
#   > Evaluating word 'night'. Perplexity: 1967.0215
#   > Evaluating word 'walk'. Perplexity: 1905.2284
#   >> Selected best word 'bake' with perplexity 1735.5079
#
#   > Evaluating word 'advent'. Perplexity: 2251.5608
#   > Evaluating word 'chimney'. Perplexity: 2434.2866
#   > Evaluating word 'laugh'. Perplexity: 2409.3396
#   > Evaluating word 'drive'. Perplexity: 2431.3438
#   > Evaluating word 'ornament'. Perplexity: 2227.6428
#   > Evaluating word 'fireplace'. Perplexity: 2436.8940
#   > Evaluating word 'jump'. Perplexity: 2131.4524
#   > Evaluating word 'night'. Perplexity: 1900.8909
#   > Evaluating word 'walk'. Perplexity: 2130.1355
#   >> Selected best word 'night' with perplexity 1900.8909
#
#   > Evaluating word 'advent'. Perplexity: 1840.9049
#   > Evaluating word 'chimney'. Perplexity: 2178.7961
#   > Evaluating word 'laugh'. Perplexity: 2362.9753
#   > Evaluating word 'drive'. Perplexity: 2091.4138
#   > Evaluating word 'ornament'. Perplexity: 2181.6228
#   > Evaluating word 'fireplace'. Perplexity: 2376.8127
#   > Evaluating word 'jump'. Perplexity: 2261.1816
#   > Evaluating word 'walk'. Perplexity: 1900.7993
#   >> Selected best word 'advent' with perplexity 1840.9049
#
#   > Evaluating word 'chimney'. Perplexity: 2245.7053
#   > Evaluating word 'laugh'. Perplexity: 2306.0325
#   > Evaluating word 'drive'. Perplexity: 2562.6443
#   > Evaluating word 'ornament'. Perplexity: 1942.1471
#   > Evaluating word 'fireplace'. Perplexity: 2296.0938
#   > Evaluating word 'jump'. Perplexity: 2734.0386
#   > Evaluating word 'walk'. Perplexity: 2068.4194
#   >> Selected best word 'ornament' with perplexity 1942.1471
#
#   > Evaluating word 'chimney'. Perplexity: 2278.2937
#   > Evaluating word 'laugh'. Perplexity: 2210.8435
#   > Evaluating word 'drive'. Perplexity: 2641.7104
#   > Evaluating word 'fireplace'. Perplexity: 2114.7644
#   > Evaluating word 'jump'. Perplexity: 2542.2834
#   > Evaluating word 'walk'. Perplexity: 2480.1489
#   >> Selected best word 'fireplace' with perplexity 2114.7644
#
#   > Evaluating word 'chimney'. Perplexity: 1875.3624
#   > Evaluating word 'laugh'. Perplexity: 2470.4243
#   > Evaluating word 'drive'. Perplexity: 2607.2485
#   > Evaluating word 'jump'. Perplexity: 2736.9043
#   > Evaluating word 'walk'. Perplexity: 2431.0076
#   >> Selected best word 'chimney' with perplexity 1875.3624
#
#   > Evaluating word 'jump'. Perplexity: 2246.8516
#   > Evaluating word 'walk'. Perplexity: 2049.0276
#   > Evaluating word 'laugh'. Perplexity: 2275.7856
#   > Evaluating word 'drive'. Perplexity: 2429.9309
#   >> Selected best word 'walk' with perplexity 2049.0276
#
#   > Evaluating word 'jump'. Perplexity: 2579.3354
#   > Evaluating word 'laugh'. Perplexity: 2274.4426
#   > Evaluating word 'drive'. Perplexity: 2177.7168
#   >> Selected best word 'drive' with perplexity 2177.7168
#
#   > Evaluating word 'jump'. Perplexity: 2671.8904
#   > Evaluating word 'laugh'. Perplexity: 2269.9397
#   >> Selected best word 'laugh' with perplexity 2269.9397
#
#   > Evaluating word 'jump'. Perplexity: 2130.1426
#   >> Selected best word 'jump' with perplexity 2130.1426
#
#   > Evaluating word 'nutcracker'. Perplexity: 7252.9531
#   > Evaluating word 'naughty'. Perplexity: 22418.9746
#   > Evaluating word 'nice'. Perplexity: 20865.2207
#   > Evaluating word 'chimney'. Perplexity: 27176.3418
#   > Evaluating word 'workshop'. Perplexity: 23780.2695
#   > Evaluating word 'gifts'. Perplexity: 11974.8848
#   > Evaluating word 'polar'. Perplexity: 26996.2441
#   > Evaluating word 'magi'. Perplexity: 52500.4492
#   > Evaluating word 'stocking'. Perplexity: 13647.6191
#   > Evaluating word 'grinch'. Perplexity: 10758.5068
#   > Evaluating word 'jingle'. Perplexity: 14202.7734
#   > Evaluating word 'sleigh'. Perplexity: 20764.6562
#   > Evaluating word 'holly'. Perplexity: 15117.6484
#   > Evaluating word 'decorations'. Perplexity: 11007.7041
#   >> Selected best word 'nutcracker' with perplexity 7252.9531
#
#   > Evaluating word 'naughty'. Perplexity: 8324.7002
#   > Evaluating word 'nice'. Perplexity: 8959.4561
#   > Evaluating word 'chimney'. Perplexity: 10391.7539
#   > Evaluating word 'workshop'. Perplexity: 8679.0840
#   > Evaluating word 'gifts'. Perplexity: 5566.6353
#   > Evaluating word 'polar'. Perplexity: 7979.3364
#   > Evaluating word 'magi'. Perplexity: 17869.4316
#   > Evaluating word 'stocking'. Perplexity: 5567.7183
#   > Evaluating word 'grinch'. Perplexity: 4374.4761
#   > Evaluating word 'jingle'. Perplexity: 6519.9585
#   > Evaluating word 'sleigh'. Perplexity: 7132.9448
#   > Evaluating word 'holly'. Perplexity: 7315.5991
#   > Evaluating word 'decorations'. Perplexity: 5266.7666
#   >> Selected best word 'grinch' with perplexity 4374.4761
#
#   > Evaluating word 'naughty'. Perplexity: 4049.0718
#   > Evaluating word 'nice'. Perplexity: 5307.3101
#   > Evaluating word 'chimney'. Perplexity: 5048.8345
#   > Evaluating word 'workshop'. Perplexity: 5783.3081
#   > Evaluating word 'gifts'. Perplexity: 3647.7373
#   > Evaluating word 'polar'. Perplexity: 4536.8521
#   > Evaluating word 'magi'. Perplexity: 9244.3623
#   > Evaluating word 'stocking'. Perplexity: 3743.9900
#   > Evaluating word 'jingle'. Perplexity: 3983.6821
#   > Evaluating word 'sleigh'. Perplexity: 4304.8369
#   > Evaluating word 'holly'. Perplexity: 4198.3477
#   > Evaluating word 'decorations'. Perplexity: 3447.6060
#   >> Selected best word 'decorations' with perplexity 3447.6060
#
#   > Evaluating word 'naughty'. Perplexity: 3652.9800
#   > Evaluating word 'nice'. Perplexity: 3730.2900
#   > Evaluating word 'chimney'. Perplexity: 4237.1514
#   > Evaluating word 'workshop'. Perplexity: 4459.8364
#   > Evaluating word 'gifts'. Perplexity: 2784.3318
#   > Evaluating word 'polar'. Perplexity: 4722.1753
#   > Evaluating word 'magi'. Perplexity: 8957.6025
#   > Evaluating word 'stocking'. Perplexity: 3078.6855
#   > Evaluating word 'jingle'. Perplexity: 3723.7429
#   > Evaluating word 'sleigh'. Perplexity: 4307.6172
#   > Evaluating word 'holly'. Perplexity: 3636.5183
#   >> Selected best word 'gifts' with perplexity 2784.3318
#
#   > Evaluating word 'naughty'. Perplexity: 2877.0190
#   > Evaluating word 'nice'. Perplexity: 2923.3901
#   > Evaluating word 'chimney'. Perplexity: 3853.7778
#   > Evaluating word 'workshop'. Perplexity: 3657.3408
#   > Evaluating word 'polar'. Perplexity: 4037.1572
#   > Evaluating word 'magi'. Perplexity: 5661.5435
#   > Evaluating word 'stocking'. Perplexity: 2196.6123
#   > Evaluating word 'jingle'. Perplexity: 3298.3235
#   > Evaluating word 'sleigh'. Perplexity: 3558.7515
#   > Evaluating word 'holly'. Perplexity: 3281.0215
#   >> Selected best word 'stocking' with perplexity 2196.6123
#
#   > Evaluating word 'naughty'. Perplexity: 2770.1235
#   > Evaluating word 'nice'. Perplexity: 2625.2502
#   > Evaluating word 'chimney'. Perplexity: 2857.0483
#   > Evaluating word 'workshop'. Perplexity: 3426.7876
#   > Evaluating word 'polar'. Perplexity: 3328.4751
#   > Evaluating word 'magi'. Perplexity: 4241.6348
#   > Evaluating word 'jingle'. Perplexity: 2394.5522
#   > Evaluating word 'sleigh'. Perplexity: 2795.1399
#   > Evaluating word 'holly'. Perplexity: 2767.1345
#   >> Selected best word 'jingle' with perplexity 2394.5522
#
#   > Evaluating word 'naughty'. Perplexity: 2924.7468
#   > Evaluating word 'nice'. Perplexity: 2646.8965
#   > Evaluating word 'chimney'. Perplexity: 3181.3643
#   > Evaluating word 'workshop'. Perplexity: 3117.8145
#   > Evaluating word 'polar'. Perplexity: 3309.5942
#   > Evaluating word 'magi'. Perplexity: 3498.2761
#   > Evaluating word 'sleigh'. Perplexity: 2186.3821
#   > Evaluating word 'holly'. Perplexity: 2464.2065
#   >> Selected best word 'sleigh' with perplexity 2186.3821
#
#   > Evaluating word 'naughty'. Perplexity: 2239.9175
#   > Evaluating word 'nice'. Perplexity: 2342.0513
#   > Evaluating word 'chimney'. Perplexity: 2578.0923
#   > Evaluating word 'workshop'. Perplexity: 2512.3391
#   > Evaluating word 'polar'. Perplexity: 2556.4248
#   > Evaluating word 'magi'. Perplexity: 3546.6118
#   > Evaluating word 'holly'. Perplexity: 2059.3291
#   >> Selected best word 'holly' with perplexity 2059.3291
#
#   > Evaluating word 'naughty'. Perplexity: 2084.5103
#   > Evaluating word 'nice'. Perplexity: 2190.7234
#   > Evaluating word 'chimney'. Perplexity: 2719.9456
#   > Evaluating word 'workshop'. Perplexity: 2328.0608
#   > Evaluating word 'polar'. Perplexity: 2422.9065
#   > Evaluating word 'magi'. Perplexity: 3061.7590
#   >> Selected best word 'naughty' with perplexity 2084.5103
#
#   > Evaluating word 'nice'. Perplexity: 1578.5480
#   > Evaluating word 'chimney'. Perplexity: 2174.9700
#   > Evaluating word 'workshop'. Perplexity: 2363.9739
#   > Evaluating word 'polar'. Perplexity: 2178.5623
#   > Evaluating word 'magi'. Perplexity: 3270.6152
#   >> Selected best word 'nice' with perplexity 1578.5480
#
#   > Evaluating word 'workshop'. Perplexity: 1754.7385
#   > Evaluating word 'polar'. Perplexity: 1611.3992
#   > Evaluating word 'magi'. Perplexity: 2546.0830
#   > Evaluating word 'chimney'. Perplexity: 1679.9774
#   >> Selected best word 'polar' with perplexity 1611.3992
#
#   > Evaluating word 'workshop'. Perplexity: 1947.2463
#   > Evaluating word 'chimney'. Perplexity: 2081.8987
#   > Evaluating word 'magi'. Perplexity: 2735.5212
#   >> Selected best word 'workshop' with perplexity 1947.2463
#
#   > Evaluating word 'chimney'. Perplexity: 2011.1222
#   > Evaluating word 'magi'. Perplexity: 2772.9001
#   >> Selected best word 'chimney' with perplexity 2011.1222
#
#   > Evaluating word 'magi'. Perplexity: 2694.4854
#   >> Selected best word 'magi' with perplexity 2694.4854
#
#   > Evaluating word 'holiday'. Perplexity: 11301.7959
#   > Evaluating word 'nutcracker'. Perplexity: 8818.6016
#   > Evaluating word 'chimney'. Perplexity: 13469.2090
#   > Evaluating word 'the'. Perplexity: 11322.9414
#   > Evaluating word 'magi'. Perplexity: 22938.1094
#   > Evaluating word 'stocking'. Perplexity: 12857.5088
#   > Evaluating word 'grinch'. Perplexity: 10282.1133
#   > Evaluating word 'and'. Perplexity: 10994.2441
#   > Evaluating word 'is'. Perplexity: 14882.0791
#   > Evaluating word 'ornament'. Perplexity: 12239.0967
#   > Evaluating word 'of'. Perplexity: 13732.8350
#   > Evaluating word 'cheer'. Perplexity: 13061.3057
#   > Evaluating word 'jingle'. Perplexity: 12817.1201
#   > Evaluating word 'eat'. Perplexity: 11969.0850
#   > Evaluating word 'naughty'. Perplexity: 14007.7246
#   > Evaluating word 'nice'. Perplexity: 13695.3516
#   > Evaluating word 'workshop'. Perplexity: 18489.6680
#   > Evaluating word 'polar'. Perplexity: 21262.2656
#   > Evaluating word 'sleigh'. Perplexity: 13992.5439
#   > Evaluating word 'holly'. Perplexity: 12988.7637
#   >> Selected best word 'nutcracker' with perplexity 8818.6016
#
#   > Evaluating word 'holiday'. Perplexity: 6491.4185
#   > Evaluating word 'chimney'. Perplexity: 8317.7168
#   > Evaluating word 'the'. Perplexity: 6836.4038
#   > Evaluating word 'magi'. Perplexity: 12525.5869
#   > Evaluating word 'stocking'. Perplexity: 7039.2017
#   > Evaluating word 'grinch'. Perplexity: 5897.0254
#   > Evaluating word 'and'. Perplexity: 6680.5928
#   > Evaluating word 'is'. Perplexity: 7854.7144
#   > Evaluating word 'ornament'. Perplexity: 6743.7725
#   > Evaluating word 'of'. Perplexity: 7575.3320
#   > Evaluating word 'cheer'. Perplexity: 8078.8477
#   > Evaluating word 'jingle'. Perplexity: 7394.4741
#   > Evaluating word 'eat'. Perplexity: 8315.1553
#   > Evaluating word 'naughty'. Perplexity: 8068.7837
#   > Evaluating word 'nice'. Perplexity: 8633.9922
#   > Evaluating word 'workshop'. Perplexity: 9006.3330
#   > Evaluating word 'polar'. Perplexity: 9202.9053
#   > Evaluating word 'sleigh'. Perplexity: 7565.3257
#   > Evaluating word 'holly'. Perplexity: 7664.4082
#   >> Selected best word 'grinch' with perplexity 5897.0254
#
#   > Evaluating word 'naughty'. Perplexity: 5129.5845
#   > Evaluating word 'nice'. Perplexity: 6034.0830
#   > Evaluating word 'chimney'. Perplexity: 5461.5493
#   > Evaluating word 'the'. Perplexity: 4744.8413
#   > Evaluating word 'eat'. Perplexity: 5669.1992
#   > Evaluating word 'workshop'. Perplexity: 6647.9189
#   > Evaluating word 'polar'. Perplexity: 5783.4297
#   > Evaluating word 'magi'. Perplexity: 7989.7534
#   > Evaluating word 'ornament'. Perplexity: 4780.7056
#   > Evaluating word 'of'. Perplexity: 4993.8794
#   > Evaluating word 'stocking'. Perplexity: 4972.3706
#   > Evaluating word 'holiday'. Perplexity: 4508.6436
#   > Evaluating word 'cheer'. Perplexity: 5347.9512
#   > Evaluating word 'jingle'. Perplexity: 5069.9536
#   > Evaluating word 'sleigh'. Perplexity: 5314.6138
#   > Evaluating word 'holly'. Perplexity: 5078.7754
#   > Evaluating word 'and'. Perplexity: 4824.0586
#   > Evaluating word 'is'. Perplexity: 5496.1284
#   >> Selected best word 'holiday' with perplexity 4508.6436
#
#   > Evaluating word 'naughty'. Perplexity: 4264.8608
#   > Evaluating word 'nice'. Perplexity: 4401.8242
#   > Evaluating word 'chimney'. Perplexity: 4598.5815
#   > Evaluating word 'the'. Perplexity: 3810.3770
#   > Evaluating word 'eat'. Perplexity: 4710.7861
#   > Evaluating word 'workshop'. Perplexity: 5000.7373
#   > Evaluating word 'polar'. Perplexity: 5257.2871
#   > Evaluating word 'magi'. Perplexity: 6539.9800
#   > Evaluating word 'ornament'. Perplexity: 3663.4883
#   > Evaluating word 'of'. Perplexity: 4166.4229
#   > Evaluating word 'stocking'. Perplexity: 3802.6047
#   > Evaluating word 'cheer'. Perplexity: 3768.5320
#   > Evaluating word 'jingle'. Perplexity: 4150.6821
#   > Evaluating word 'sleigh'. Perplexity: 4317.3438
#   > Evaluating word 'holly'. Perplexity: 4030.6675
#   > Evaluating word 'and'. Perplexity: 4025.3201
#   > Evaluating word 'is'. Perplexity: 4338.0459
#   >> Selected best word 'ornament' with perplexity 3663.4883
#
#   > Evaluating word 'naughty'. Perplexity: 3630.9805
#   > Evaluating word 'nice'. Perplexity: 3808.6621
#   > Evaluating word 'chimney'. Perplexity: 3869.5364
#   > Evaluating word 'the'. Perplexity: 3135.7148
#   > Evaluating word 'eat'. Perplexity: 4022.5034
#   > Evaluating word 'workshop'. Perplexity: 4320.3423
#   > Evaluating word 'polar'. Perplexity: 4235.9268
#   > Evaluating word 'magi'. Perplexity: 5976.1787
#   > Evaluating word 'of'. Perplexity: 3313.2480
#   > Evaluating word 'stocking'. Perplexity: 3196.9849
#   > Evaluating word 'cheer'. Perplexity: 3492.7725
#   > Evaluating word 'jingle'. Perplexity: 3339.0908
#   > Evaluating word 'sleigh'. Perplexity: 3855.7007
#   > Evaluating word 'holly'. Perplexity: 3459.6409
#   > Evaluating word 'and'. Perplexity: 3205.3896
#   > Evaluating word 'is'. Perplexity: 3326.2158
#   >> Selected best word 'the' with perplexity 3135.7148
#
#   > Evaluating word 'naughty'. Perplexity: 3070.4668
#   > Evaluating word 'nice'. Perplexity: 3223.5623
#   > Evaluating word 'chimney'. Perplexity: 3651.4685
#   > Evaluating word 'eat'. Perplexity: 3907.5474
#   > Evaluating word 'workshop'. Perplexity: 3430.7312
#   > Evaluating word 'polar'. Perplexity: 2894.4670
#   > Evaluating word 'magi'. Perplexity: 3629.1733
#   > Evaluating word 'of'. Perplexity: 2918.8843
#   > Evaluating word 'stocking'. Perplexity: 3425.6277
#   > Evaluating word 'cheer'. Perplexity: 3280.4646
#   > Evaluating word 'jingle'. Perplexity: 3247.9775
#   > Evaluating word 'sleigh'. Perplexity: 3243.4458
#   > Evaluating word 'holly'. Perplexity: 2806.9858
#   > Evaluating word 'and'. Perplexity: 3011.2910
#   > Evaluating word 'is'. Perplexity: 2994.0354
#   >> Selected best word 'holly' with perplexity 2806.9858
#
#   > Evaluating word 'naughty'. Perplexity: 2952.7913
#   > Evaluating word 'nice'. Perplexity: 2871.5928
#   > Evaluating word 'chimney'. Perplexity: 3802.4524
#   > Evaluating word 'eat'. Perplexity: 3718.5510
#   > Evaluating word 'workshop'. Perplexity: 3113.2002
#   > Evaluating word 'polar'. Perplexity: 3524.5537
#   > Evaluating word 'magi'. Perplexity: 3889.3669
#   > Evaluating word 'of'. Perplexity: 2748.8716
#   > Evaluating word 'stocking'. Perplexity: 2910.9255
#   > Evaluating word 'cheer'. Perplexity: 2684.2300
#   > Evaluating word 'jingle'. Perplexity: 2712.1348
#   > Evaluating word 'sleigh'. Perplexity: 3066.3086
#   > Evaluating word 'and'. Perplexity: 2202.7988
#   > Evaluating word 'is'. Perplexity: 2544.8752
#   >> Selected best word 'and' with perplexity 2202.7988
#
#   > Evaluating word 'naughty'. Perplexity: 2472.4856
#   > Evaluating word 'nice'. Perplexity: 2460.0388
#   > Evaluating word 'chimney'. Perplexity: 3030.6111
#   > Evaluating word 'eat'. Perplexity: 2906.9111
#   > Evaluating word 'workshop'. Perplexity: 3048.6648
#   > Evaluating word 'polar'. Perplexity: 3147.7656
#   > Evaluating word 'magi'. Perplexity: 3324.2117
#   > Evaluating word 'of'. Perplexity: 2247.1301
#   > Evaluating word 'stocking'. Perplexity: 2344.8547
#   > Evaluating word 'cheer'. Perplexity: 2097.0608
#   > Evaluating word 'jingle'. Perplexity: 2247.6433
#   > Evaluating word 'sleigh'. Perplexity: 2553.5093
#   > Evaluating word 'is'. Perplexity: 2354.5913
#   >> Selected best word 'cheer' with perplexity 2097.0608
#
#   > Evaluating word 'naughty'. Perplexity: 2210.1562
#   > Evaluating word 'nice'. Perplexity: 2485.6519
#   > Evaluating word 'chimney'. Perplexity: 2503.9719
#   > Evaluating word 'eat'. Perplexity: 2340.8174
#   > Evaluating word 'workshop'. Perplexity: 2460.3848
#   > Evaluating word 'polar'. Perplexity: 2423.5293
#   > Evaluating word 'magi'. Perplexity: 3122.2419
#   > Evaluating word 'of'. Perplexity: 1731.7368
#   > Evaluating word 'stocking'. Perplexity: 2054.1177
#   > Evaluating word 'cheer'. Perplexity: 1978.1780
#   > Evaluating word 'jingle'. Perplexity: 1915.0763
#   > Evaluating word 'sleigh'. Perplexity: 2258.4048
#   > Evaluating word 'is'. Perplexity: 1844.2031
#   >> Selected best word 'of' with perplexity 1731.7368
#
#   > Evaluating word 'naughty'. Perplexity: 2032.5217
#   > Evaluating word 'nice'. Perplexity: 2221.0000
#   > Evaluating word 'chimney'. Perplexity: 2321.7605
#   > Evaluating word 'eat'. Perplexity: 2203.3640
#   > Evaluating word 'workshop'. Perplexity: 2332.9714
#   > Evaluating word 'polar'. Perplexity: 2210.1648
#   > Evaluating word 'magi'. Perplexity: 2649.0708
#   > Evaluating word 'stocking'. Perplexity: 2077.4856
#   > Evaluating word 'cheer'. Perplexity: 1894.5592
#   > Evaluating word 'jingle'. Perplexity: 1758.3578
#   > Evaluating word 'sleigh'. Perplexity: 2051.5139
#   > Evaluating word 'is'. Perplexity: 1856.5760
#   >> Selected best word 'jingle' with perplexity 1758.3578
#
#   > Evaluating word 'naughty'. Perplexity: 2132.0327
#   > Evaluating word 'nice'. Perplexity: 2020.8978
#   > Evaluating word 'chimney'. Perplexity: 2317.6204
#   > Evaluating word 'eat'. Perplexity: 2193.0801
#   > Evaluating word 'workshop'. Perplexity: 2098.3604
#   > Evaluating word 'polar'. Perplexity: 2364.9705
#   > Evaluating word 'magi'. Perplexity: 2316.9795
#   > Evaluating word 'stocking'. Perplexity: 2036.8071
#   > Evaluating word 'cheer'. Perplexity: 1903.8489
#   > Evaluating word 'sleigh'. Perplexity: 1774.4301
#   > Evaluating word 'is'. Perplexity: 1737.8706
#   >> Selected best word 'is' with perplexity 1737.8706
#
#   > Evaluating word 'naughty'. Perplexity: 1875.0190
#   > Evaluating word 'nice'. Perplexity: 1780.5283
#   > Evaluating word 'chimney'. Perplexity: 2128.5820
#   > Evaluating word 'workshop'. Perplexity: 2324.2229
#   > Evaluating word 'polar'. Perplexity: 2633.9182
#   > Evaluating word 'magi'. Perplexity: 2475.0959
#   > Evaluating word 'stocking'. Perplexity: 2009.8021
#   > Evaluating word 'cheer'. Perplexity: 1912.2549
#   > Evaluating word 'sleigh'. Perplexity: 1781.0853
#   > Evaluating word 'eat'. Perplexity: 2629.1562
#   >> Selected best word 'nice' with perplexity 1780.5283
#
#   > Evaluating word 'naughty'. Perplexity: 1802.9156
#   > Evaluating word 'chimney'. Perplexity: 2079.6802
#   > Evaluating word 'workshop'. Perplexity: 2040.6121
#   > Evaluating word 'polar'. Perplexity: 2161.0200
#   > Evaluating word 'magi'. Perplexity: 2647.7815
#   > Evaluating word 'stocking'. Perplexity: 1732.8552
#   > Evaluating word 'cheer'. Perplexity: 1739.6755
#   > Evaluating word 'sleigh'. Perplexity: 1909.6497
#   > Evaluating word 'eat'. Perplexity: 1979.5840
#   >> Selected best word 'stocking' with perplexity 1732.8552
#
#   > Evaluating word 'naughty'. Perplexity: 1799.4673
#   > Evaluating word 'chimney'. Perplexity: 1831.7755
#   > Evaluating word 'workshop'. Perplexity: 2098.6013
#   > Evaluating word 'polar'. Perplexity: 2070.3269
#   > Evaluating word 'magi'. Perplexity: 2353.9302
#   > Evaluating word 'cheer'. Perplexity: 1778.3230
#   > Evaluating word 'sleigh'. Perplexity: 1892.9067
#   > Evaluating word 'eat'. Perplexity: 2064.4504
#   >> Selected best word 'cheer' with perplexity 1778.3230
#
#   > Evaluating word 'naughty'. Perplexity: 2003.1794
#   > Evaluating word 'chimney'. Perplexity: 1996.8251
#   > Evaluating word 'workshop'. Perplexity: 2208.4097
#   > Evaluating word 'polar'. Perplexity: 2099.4912
#   > Evaluating word 'magi'. Perplexity: 2424.2703
#   > Evaluating word 'sleigh'. Perplexity: 1854.0557
#   > Evaluating word 'eat'. Perplexity: 1956.4866
#   >> Selected best word 'sleigh' with perplexity 1854.0557
#
#   > Evaluating word 'naughty'. Perplexity: 1879.2546
#   > Evaluating word 'chimney'. Perplexity: 1937.9093
#   > Evaluating word 'workshop'. Perplexity: 2017.7029
#   > Evaluating word 'polar'. Perplexity: 2052.7488
#   > Evaluating word 'magi'. Perplexity: 2445.4287
#   > Evaluating word 'eat'. Perplexity: 2011.2479
#   >> Selected best word 'naughty' with perplexity 1879.2546
#
#   > Evaluating word 'chimney'. Perplexity: 1925.0953
#   > Evaluating word 'workshop'. Perplexity: 2061.5063
#   > Evaluating word 'polar'. Perplexity: 1947.7051
#   > Evaluating word 'magi'. Perplexity: 2524.9541
#   > Evaluating word 'eat'. Perplexity: 2040.5682
#   >> Selected best word 'chimney' with perplexity 1925.0953
#
#   > Evaluating word 'workshop'. Perplexity: 2138.2239
#   > Evaluating word 'polar'. Perplexity: 2206.4919
#   > Evaluating word 'magi'. Perplexity: 2483.9600
#   > Evaluating word 'eat'. Perplexity: 2083.9526
#   >> Selected best word 'eat' with perplexity 2083.9526
#
#   > Evaluating word 'workshop'. Perplexity: 2444.7197
#   > Evaluating word 'polar'. Perplexity: 2346.7822
#   > Evaluating word 'magi'. Perplexity: 2732.0042
#   >> Selected best word 'polar' with perplexity 2346.7822
#
#   > Evaluating word 'workshop'. Perplexity: 2639.2515
#   > Evaluating word 'magi'. Perplexity: 3198.9001
#   >> Selected best word 'workshop' with perplexity 2639.2515
#
#   > Evaluating word 'magi'. Perplexity: 3213.7029
#   >> Selected best word 'magi' with perplexity 3213.7029
#
#   > Evaluating word 'cookie'. Perplexity: 11866.4990
#   > Evaluating word 'joy'. Perplexity: 13120.8320
#   > Evaluating word 'paper'. Perplexity: 12713.1084
#   > Evaluating word 'dream'. Perplexity: 12718.1172
#   > Evaluating word 'night'. Perplexity: 13211.8779
#   > Evaluating word 'you'. Perplexity: 12421.6895
#   > Evaluating word 'peace'. Perplexity: 13601.8037
#   > Evaluating word 'to'. Perplexity: 12543.6133
#   > Evaluating word 'from'. Perplexity: 13383.2158
#   > Evaluating word 'angel'. Perplexity: 12545.6348
#   > Evaluating word 'wonder'. Perplexity: 14038.2432
#   > Evaluating word 'star'. Perplexity: 12207.7617
#   > Evaluating word 'the'. Perplexity: 12424.5801
#   > Evaluating word 'as'. Perplexity: 14208.8428
#   > Evaluating word 'candy'. Perplexity: 11238.2334
#   > Evaluating word 'fireplace'. Perplexity: 13312.1611
#   > Evaluating word 'hohoho'. Perplexity: 11181.8926
#   > Evaluating word 'not'. Perplexity: 13695.6914
#   > Evaluating word 'bow'. Perplexity: 14363.5869
#   > Evaluating word 'and'. Perplexity: 11885.7305
#   > Evaluating word 'with'. Perplexity: 12234.4980
#   > Evaluating word 'game'. Perplexity: 12554.1084
#   > Evaluating word 'milk'. Perplexity: 12799.9580
#   > Evaluating word 'in'. Perplexity: 12322.5664
#   > Evaluating word 'wreath'. Perplexity: 12323.4014
#   > Evaluating word 'of'. Perplexity: 12692.0303
#   > Evaluating word 'season'. Perplexity: 13419.8711
#   > Evaluating word 'merry'. Perplexity: 11877.4590
#   > Evaluating word 'workshop'. Perplexity: 16727.2188
#   > Evaluating word 'it'. Perplexity: 13677.2217
#   > Evaluating word 'we'. Perplexity: 14177.3994
#   > Evaluating word 'wrapping'. Perplexity: 13719.8760
#   > Evaluating word 'that'. Perplexity: 13837.2305
#   > Evaluating word 'poinsettia'. Perplexity: 6057.5269
#   > Evaluating word 'greeting'. Perplexity: 13333.3408
#   >> Selected best word 'poinsettia' with perplexity 6057.5269
#
#   > Evaluating word 'cookie'. Perplexity: 5026.0488
#   > Evaluating word 'joy'. Perplexity: 5546.2231
#   > Evaluating word 'paper'. Perplexity: 5480.2695
#   > Evaluating word 'dream'. Perplexity: 5645.7134
#   > Evaluating word 'night'. Perplexity: 5748.6821
#   > Evaluating word 'you'. Perplexity: 5341.6514
#   > Evaluating word 'peace'. Perplexity: 5632.6235
#   > Evaluating word 'to'. Perplexity: 5506.8843
#   > Evaluating word 'from'. Perplexity: 6012.3301
#   > Evaluating word 'angel'. Perplexity: 5199.2944
#   > Evaluating word 'wonder'. Perplexity: 6217.1177
#   > Evaluating word 'star'. Perplexity: 5024.1318
#   > Evaluating word 'the'. Perplexity: 5337.2871
#   > Evaluating word 'as'. Perplexity: 6075.4209
#   > Evaluating word 'candy'. Perplexity: 4836.8237
#   > Evaluating word 'fireplace'. Perplexity: 5746.2920
#   > Evaluating word 'hohoho'. Perplexity: 5205.8340
#   > Evaluating word 'not'. Perplexity: 5914.6484
#   > Evaluating word 'bow'. Perplexity: 5698.8452
#   > Evaluating word 'and'. Perplexity: 5089.7969
#   > Evaluating word 'with'. Perplexity: 5482.5122
#   > Evaluating word 'game'. Perplexity: 6048.0312
#   > Evaluating word 'milk'. Perplexity: 5752.1587
#   > Evaluating word 'in'. Perplexity: 5426.1528
#   > Evaluating word 'wreath'. Perplexity: 4898.4102
#   > Evaluating word 'of'. Perplexity: 5763.2837
#   > Evaluating word 'season'. Perplexity: 5817.4941
#   > Evaluating word 'merry'. Perplexity: 5243.5674
#   > Evaluating word 'workshop'. Perplexity: 7337.7275
#   > Evaluating word 'it'. Perplexity: 5840.6084
#   > Evaluating word 'we'. Perplexity: 6151.3994
#   > Evaluating word 'wrapping'. Perplexity: 5681.5723
#   > Evaluating word 'that'. Perplexity: 6024.6704
#   > Evaluating word 'greeting'. Perplexity: 5721.9736
#   >> Selected best word 'candy' with perplexity 4836.8237
#
#   > Evaluating word 'cookie'. Perplexity: 4138.2041
#   > Evaluating word 'joy'. Perplexity: 4703.1641
#   > Evaluating word 'paper'. Perplexity: 4925.3403
#   > Evaluating word 'dream'. Perplexity: 4915.8843
#   > Evaluating word 'night'. Perplexity: 4647.8740
#   > Evaluating word 'you'. Perplexity: 4556.2681
#   > Evaluating word 'peace'. Perplexity: 4781.0933
#   > Evaluating word 'to'. Perplexity: 4723.3735
#   > Evaluating word 'from'. Perplexity: 4909.1147
#   > Evaluating word 'angel'. Perplexity: 4879.7041
#   > Evaluating word 'wonder'. Perplexity: 5906.6440
#   > Evaluating word 'star'. Perplexity: 4268.2705
#   > Evaluating word 'the'. Perplexity: 4500.1421
#   > Evaluating word 'as'. Perplexity: 5053.7046
#   > Evaluating word 'fireplace'. Perplexity: 4854.3794
#   > Evaluating word 'hohoho'. Perplexity: 4319.7036
#   > Evaluating word 'not'. Perplexity: 5031.6841
#   > Evaluating word 'bow'. Perplexity: 4839.7910
#   > Evaluating word 'and'. Perplexity: 4381.5449
#   > Evaluating word 'with'. Perplexity: 4541.7090
#   > Evaluating word 'game'. Perplexity: 4812.6904
#   > Evaluating word 'milk'. Perplexity: 4453.2993
#   > Evaluating word 'in'. Perplexity: 4474.1455
#   > Evaluating word 'wreath'. Perplexity: 4078.8643
#   > Evaluating word 'of'. Perplexity: 4840.3677
#   > Evaluating word 'season'. Perplexity: 4996.2944
#   > Evaluating word 'merry'. Perplexity: 4554.9082
#   > Evaluating word 'workshop'. Perplexity: 5638.1270
#   > Evaluating word 'it'. Perplexity: 5015.4478
#   > Evaluating word 'we'. Perplexity: 5248.7656
#   > Evaluating word 'wrapping'. Perplexity: 5014.3237
#   > Evaluating word 'that'. Perplexity: 5144.5757
#   > Evaluating word 'greeting'. Perplexity: 5330.0796
#   >> Selected best word 'wreath' with perplexity 4078.8643
#
#   > Evaluating word 'cookie'. Perplexity: 3455.4268
#   > Evaluating word 'joy'. Perplexity: 3828.7356
#   > Evaluating word 'paper'. Perplexity: 3783.5847
#   > Evaluating word 'dream'. Perplexity: 3983.4390
#   > Evaluating word 'night'. Perplexity: 4043.7695
#   > Evaluating word 'you'. Perplexity: 3789.5610
#   > Evaluating word 'peace'. Perplexity: 3993.4272
#   > Evaluating word 'to'. Perplexity: 3874.9502
#   > Evaluating word 'from'. Perplexity: 4140.6162
#   > Evaluating word 'angel'. Perplexity: 3653.0776
#   > Evaluating word 'wonder'. Perplexity: 4360.1113
#   > Evaluating word 'star'. Perplexity: 3484.2556
#   > Evaluating word 'the'. Perplexity: 3757.7405
#   > Evaluating word 'as'. Perplexity: 4200.6548
#   > Evaluating word 'fireplace'. Perplexity: 3867.2493
#   > Evaluating word 'hohoho'. Perplexity: 3558.9246
#   > Evaluating word 'not'. Perplexity: 4153.7710
#   > Evaluating word 'bow'. Perplexity: 3733.0518
#   > Evaluating word 'and'. Perplexity: 3608.9585
#   > Evaluating word 'with'. Perplexity: 3730.0303
#   > Evaluating word 'game'. Perplexity: 4219.9399
#   > Evaluating word 'milk'. Perplexity: 4016.8030
#   > Evaluating word 'in'. Perplexity: 3757.7620
#   > Evaluating word 'of'. Perplexity: 3733.4932
#   > Evaluating word 'season'. Perplexity: 4051.7988
#   > Evaluating word 'merry'. Perplexity: 3577.5725
#   > Evaluating word 'workshop'. Perplexity: 4807.0942
#   > Evaluating word 'it'. Perplexity: 4132.3638
#   > Evaluating word 'we'. Perplexity: 4229.9199
#   > Evaluating word 'wrapping'. Perplexity: 3965.4954
#   > Evaluating word 'that'. Perplexity: 4200.5425
#   > Evaluating word 'greeting'. Perplexity: 3983.8987
#   >> Selected best word 'cookie' with perplexity 3455.4268
#
#   > Evaluating word 'joy'. Perplexity: 3268.3452
#   > Evaluating word 'paper'. Perplexity: 3329.6179
#   > Evaluating word 'dream'. Perplexity: 3363.6594
#   > Evaluating word 'night'. Perplexity: 3551.0354
#   > Evaluating word 'you'. Perplexity: 3282.7397
#   > Evaluating word 'peace'. Perplexity: 3523.3403
#   > Evaluating word 'to'. Perplexity: 3410.7693
#   > Evaluating word 'from'. Perplexity: 3610.6970
#   > Evaluating word 'angel'. Perplexity: 3158.8652
#   > Evaluating word 'wonder'. Perplexity: 3816.9089
#   > Evaluating word 'star'. Perplexity: 3011.4116
#   > Evaluating word 'the'. Perplexity: 3297.5969
#   > Evaluating word 'as'. Perplexity: 3716.4592
#   > Evaluating word 'fireplace'. Perplexity: 3369.5381
#   > Evaluating word 'hohoho'. Perplexity: 3140.5542
#   > Evaluating word 'not'. Perplexity: 3650.7581
#   > Evaluating word 'bow'. Perplexity: 3437.3203
#   > Evaluating word 'and'. Perplexity: 3129.3010
#   > Evaluating word 'with'. Perplexity: 3286.7996
#   > Evaluating word 'game'. Perplexity: 3369.6377
#   > Evaluating word 'milk'. Perplexity: 3080.6682
#   > Evaluating word 'in'. Perplexity: 3210.8660
#   > Evaluating word 'of'. Perplexity: 3514.9702
#   > Evaluating word 'season'. Perplexity: 3331.5173
#   > Evaluating word 'merry'. Perplexity: 3136.1484
#   > Evaluating word 'workshop'. Perplexity: 3873.4502
#   > Evaluating word 'it'. Perplexity: 3603.5693
#   > Evaluating word 'we'. Perplexity: 3711.5928
#   > Evaluating word 'wrapping'. Perplexity: 3413.5156
#   > Evaluating word 'that'. Perplexity: 3745.1758
#   > Evaluating word 'greeting'. Perplexity: 3517.4551
#   >> Selected best word 'star' with perplexity 3011.4116
#
#   > Evaluating word 'joy'. Perplexity: 2974.1230
#   > Evaluating word 'paper'. Perplexity: 2776.3955
#   > Evaluating word 'dream'. Perplexity: 3006.3613
#   > Evaluating word 'night'. Perplexity: 3023.4719
#   > Evaluating word 'you'. Perplexity: 2903.0229
#   > Evaluating word 'peace'. Perplexity: 2966.5640
#   > Evaluating word 'to'. Perplexity: 2973.4268
#   > Evaluating word 'from'. Perplexity: 3181.3762
#   > Evaluating word 'angel'. Perplexity: 2775.5896
#   > Evaluating word 'wonder'. Perplexity: 3258.5820
#   > Evaluating word 'the'. Perplexity: 2865.8381
#   > Evaluating word 'as'. Perplexity: 3121.6196
#   > Evaluating word 'fireplace'. Perplexity: 3035.4097
#   > Evaluating word 'hohoho'. Perplexity: 2764.2202
#   > Evaluating word 'not'. Perplexity: 3253.2195
#   > Evaluating word 'bow'. Perplexity: 2858.3264
#   > Evaluating word 'and'. Perplexity: 2777.2959
#   > Evaluating word 'with'. Perplexity: 2839.4170
#   > Evaluating word 'game'. Perplexity: 3104.4185
#   > Evaluating word 'milk'. Perplexity: 2866.1880
#   > Evaluating word 'in'. Perplexity: 2827.6311
#   > Evaluating word 'of'. Perplexity: 2747.3372
#   > Evaluating word 'season'. Perplexity: 3044.4114
#   > Evaluating word 'merry'. Perplexity: 2733.9485
#   > Evaluating word 'workshop'. Perplexity: 3655.4092
#   > Evaluating word 'it'. Perplexity: 3189.9102
#   > Evaluating word 'we'. Perplexity: 3210.0210
#   > Evaluating word 'wrapping'. Perplexity: 2921.8586
#   > Evaluating word 'that'. Perplexity: 3256.7957
#   > Evaluating word 'greeting'. Perplexity: 3152.2295
#   >> Selected best word 'merry' with perplexity 2733.9485
#
#   > Evaluating word 'joy'. Perplexity: 2640.2986
#   > Evaluating word 'paper'. Perplexity: 2777.8496
#   > Evaluating word 'dream'. Perplexity: 2812.4775
#   > Evaluating word 'night'. Perplexity: 2668.2861
#   > Evaluating word 'you'. Perplexity: 2594.6726
#   > Evaluating word 'peace'. Perplexity: 2834.7390
#   > Evaluating word 'to'. Perplexity: 2675.6848
#   > Evaluating word 'from'. Perplexity: 2838.8037
#   > Evaluating word 'angel'. Perplexity: 2781.2957
#   > Evaluating word 'wonder'. Perplexity: 2966.1777
#   > Evaluating word 'the'. Perplexity: 2536.9346
#   > Evaluating word 'as'. Perplexity: 2886.3477
#   > Evaluating word 'fireplace'. Perplexity: 2721.4062
#   > Evaluating word 'hohoho'. Perplexity: 2343.6890
#   > Evaluating word 'not'. Perplexity: 2834.5701
#   > Evaluating word 'bow'. Perplexity: 2698.9731
#   > Evaluating word 'and'. Perplexity: 2346.5908
#   > Evaluating word 'with'. Perplexity: 2613.4634
#   > Evaluating word 'game'. Perplexity: 2851.3867
#   > Evaluating word 'milk'. Perplexity: 2728.8054
#   > Evaluating word 'in'. Perplexity: 2624.9048
#   > Evaluating word 'of'. Perplexity: 2814.3464
#   > Evaluating word 'season'. Perplexity: 2549.6926
#   > Evaluating word 'workshop'. Perplexity: 3251.7400
#   > Evaluating word 'it'. Perplexity: 2721.8411
#   > Evaluating word 'we'. Perplexity: 2852.2690
#   > Evaluating word 'wrapping'. Perplexity: 2867.6111
#   > Evaluating word 'that'. Perplexity: 2926.9207
#   > Evaluating word 'greeting'. Perplexity: 2671.8499
#   >> Selected best word 'hohoho' with perplexity 2343.6890
#
#   > Evaluating word 'joy'. Perplexity: 2225.4004
#   > Evaluating word 'paper'. Perplexity: 2408.3369
#   > Evaluating word 'dream'. Perplexity: 2491.1028
#   > Evaluating word 'night'. Perplexity: 2504.0901
#   > Evaluating word 'you'. Perplexity: 2195.9399
#   > Evaluating word 'peace'. Perplexity: 2389.1985
#   > Evaluating word 'to'. Perplexity: 2277.8396
#   > Evaluating word 'from'. Perplexity: 2400.5588
#   > Evaluating word 'angel'. Perplexity: 2324.1953
#   > Evaluating word 'wonder'. Perplexity: 2582.2017
#   > Evaluating word 'the'. Perplexity: 2164.6267
#   > Evaluating word 'as'. Perplexity: 2522.4402
#   > Evaluating word 'fireplace'. Perplexity: 2322.7981
#   > Evaluating word 'not'. Perplexity: 2386.8071
#   > Evaluating word 'bow'. Perplexity: 2369.0112
#   > Evaluating word 'and'. Perplexity: 2166.0288
#   > Evaluating word 'with'. Perplexity: 2272.3992
#   > Evaluating word 'game'. Perplexity: 2428.8013
#   > Evaluating word 'milk'. Perplexity: 2415.6240
#   > Evaluating word 'in'. Perplexity: 2255.9617
#   > Evaluating word 'of'. Perplexity: 2460.0693
#   > Evaluating word 'season'. Perplexity: 2199.2566
#   > Evaluating word 'workshop'. Perplexity: 2833.8916
#   > Evaluating word 'it'. Perplexity: 2230.8901
#   > Evaluating word 'we'. Perplexity: 2335.4014
#   > Evaluating word 'wrapping'. Perplexity: 2579.8657
#   > Evaluating word 'that'. Perplexity: 2415.7725
#   > Evaluating word 'greeting'. Perplexity: 2441.2903
#   >> Selected best word 'the' with perplexity 2164.6267
#
#   > Evaluating word 'joy'. Perplexity: 1994.2292
#   > Evaluating word 'paper'. Perplexity: 2173.5339
#   > Evaluating word 'dream'. Perplexity: 2099.3220
#   > Evaluating word 'night'. Perplexity: 1948.0255
#   > Evaluating word 'you'. Perplexity: 2126.7468
#   > Evaluating word 'peace'. Perplexity: 2167.3015
#   > Evaluating word 'to'. Perplexity: 2163.9321
#   > Evaluating word 'from'. Perplexity: 2292.2725
#   > Evaluating word 'angel'. Perplexity: 2153.2737
#   > Evaluating word 'wonder'. Perplexity: 2109.2366
#   > Evaluating word 'as'. Perplexity: 2321.5193
#   > Evaluating word 'fireplace'. Perplexity: 2066.3464
#   > Evaluating word 'not'. Perplexity: 2238.4783
#   > Evaluating word 'bow'. Perplexity: 2242.8931
#   > Evaluating word 'and'. Perplexity: 2105.2776
#   > Evaluating word 'with'. Perplexity: 2155.4104
#   > Evaluating word 'game'. Perplexity: 2151.7751
#   > Evaluating word 'milk'. Perplexity: 2283.5796
#   > Evaluating word 'in'. Perplexity: 2035.8672
#   > Evaluating word 'of'. Perplexity: 2062.3323
#   > Evaluating word 'season'. Perplexity: 1955.4877
#   > Evaluating word 'workshop'. Perplexity: 2360.3120
#   > Evaluating word 'it'. Perplexity: 2194.1167
#   > Evaluating word 'we'. Perplexity: 2263.0002
#   > Evaluating word 'wrapping'. Perplexity: 2215.3623
#   > Evaluating word 'that'. Perplexity: 2206.6182
#   > Evaluating word 'greeting'. Perplexity: 2280.0630
#   >> Selected best word 'night' with perplexity 1948.0255
#
#   > Evaluating word 'joy'. Perplexity: 1950.7957
#   > Evaluating word 'paper'. Perplexity: 2250.8877
#   > Evaluating word 'dream'. Perplexity: 1969.4963
#   > Evaluating word 'you'. Perplexity: 1875.8033
#   > Evaluating word 'peace'. Perplexity: 2150.9893
#   > Evaluating word 'to'. Perplexity: 1909.0288
#   > Evaluating word 'from'. Perplexity: 2039.6646
#   > Evaluating word 'angel'. Perplexity: 1970.2346
#   > Evaluating word 'wonder'. Perplexity: 2122.3289
#   > Evaluating word 'as'. Perplexity: 2047.5529
#   > Evaluating word 'fireplace'. Perplexity: 2277.4749
#   > Evaluating word 'not'. Perplexity: 2073.2224
#   > Evaluating word 'bow'. Perplexity: 2220.8665
#   > Evaluating word 'and'. Perplexity: 1853.4537
#   > Evaluating word 'with'. Perplexity: 1878.3094
#   > Evaluating word 'game'. Perplexity: 2014.8101
#   > Evaluating word 'milk'. Perplexity: 2199.2534
#   > Evaluating word 'in'. Perplexity: 1849.3044
#   > Evaluating word 'of'. Perplexity: 1716.4161
#   > Evaluating word 'season'. Perplexity: 1877.8411
#   > Evaluating word 'workshop'. Perplexity: 2406.2029
#   > Evaluating word 'it'. Perplexity: 1887.0317
#   > Evaluating word 'we'. Perplexity: 1908.6091
#   > Evaluating word 'wrapping'. Perplexity: 2251.5684
#   > Evaluating word 'that'. Perplexity: 1906.8572
#   > Evaluating word 'greeting'. Perplexity: 2170.2986
#   >> Selected best word 'of' with perplexity 1716.4161
#
#   > Evaluating word 'joy'. Perplexity: 1563.7390
#   > Evaluating word 'paper'. Perplexity: 1871.1052
#   > Evaluating word 'dream'. Perplexity: 1909.1626
#   > Evaluating word 'you'. Perplexity: 1734.2274
#   > Evaluating word 'peace'. Perplexity: 1651.6061
#   > Evaluating word 'to'. Perplexity: 1781.1567
#   > Evaluating word 'from'. Perplexity: 1932.4613
#   > Evaluating word 'angel'. Perplexity: 1802.3990
#   > Evaluating word 'wonder'. Perplexity: 1649.7792
#   > Evaluating word 'as'. Perplexity: 1920.4231
#   > Evaluating word 'fireplace'. Perplexity: 1959.9835
#   > Evaluating word 'not'. Perplexity: 1777.7041
# ...
#   > Evaluating word 'polar'. Perplexity: 352.9214
#   > Evaluating word 'wrapping'. Perplexity: 354.1766
#   > Evaluating word 'jump'. Perplexity: 350.4101
#   > Evaluating word 'greeting'. Perplexity: 352.5618
#   > Evaluating word 'chocolate'. Perplexity: 350.3035
#   >> Selected best word 'cheer' with perplexity 334.0988
#
#   > Evaluating word 'carol'. Perplexity: 332.1290
#   > Evaluating word 'dream'. Perplexity: 345.0624
#   > Evaluating word 'sing'. Perplexity: 337.2692
#   > Evaluating word 'bake'. Perplexity: 351.1457
#   > Evaluating word 'angel'. Perplexity: 345.5573
#   > Evaluating word 'chimney'. Perplexity: 336.7219
#   > Evaluating word 'laugh'. Perplexity: 343.8112
#   > Evaluating word 'magi'. Perplexity: 363.3930
#   > Evaluating word 'walk'. Perplexity: 351.6834
#   > Evaluating word 'beard'. Perplexity: 355.9686
#   > Evaluating word 'game'. Perplexity: 349.8495
#   > Evaluating word 'milk'. Perplexity: 357.3954
#   > Evaluating word 'cheer'. Perplexity: 323.6571
#   > Evaluating word 'visit'. Perplexity: 354.3425
#   > Evaluating word 'naughty'. Perplexity: 347.8853
#   > Evaluating word 'nice'. Perplexity: 351.5035
#   > Evaluating word 'workshop'. Perplexity: 361.2414
#   > Evaluating word 'polar'. Perplexity: 352.6465
#   > Evaluating word 'wrapping'. Perplexity: 344.5307
#   > Evaluating word 'jump'. Perplexity: 347.8858
#   > Evaluating word 'greeting'. Perplexity: 343.3274
#   > Evaluating word 'chocolate'. Perplexity: 344.7417
#   >> Selected best word 'cheer' with perplexity 323.6571
#
#   > Evaluating word 'carol'. Perplexity: 323.6802
#   > Evaluating word 'dream'. Perplexity: 336.3887
#   > Evaluating word 'sing'. Perplexity: 327.4651
#   > Evaluating word 'bake'. Perplexity: 345.8562
#   > Evaluating word 'angel'. Perplexity: 337.3155
#   > Evaluating word 'chimney'. Perplexity: 326.8651
#   > Evaluating word 'laugh'. Perplexity: 333.6848
#   > Evaluating word 'magi'. Perplexity: 354.1550
#   > Evaluating word 'walk'. Perplexity: 343.0896
#   > Evaluating word 'beard'. Perplexity: 347.5729
#   > Evaluating word 'game'. Perplexity: 342.0369
#   > Evaluating word 'milk'. Perplexity: 349.2166
#   > Evaluating word 'visit'. Perplexity: 351.8970
#   > Evaluating word 'naughty'. Perplexity: 342.1083
#   > Evaluating word 'nice'. Perplexity: 342.7315
#   > Evaluating word 'workshop'. Perplexity: 356.4617
#   > Evaluating word 'polar'. Perplexity: 342.3120
#   > Evaluating word 'wrapping'. Perplexity: 344.8181
#   > Evaluating word 'jump'. Perplexity: 337.9380
#   > Evaluating word 'greeting'. Perplexity: 337.0825
#   > Evaluating word 'chocolate'. Perplexity: 337.7570
#   >> Selected best word 'carol' with perplexity 323.6802
#
#   > Evaluating word 'dream'. Perplexity: 333.3577
#   > Evaluating word 'sing'. Perplexity: 315.3770
#   > Evaluating word 'bake'. Perplexity: 338.3800
#   > Evaluating word 'angel'. Perplexity: 328.6647
#   > Evaluating word 'chimney'. Perplexity: 329.6364
#   > Evaluating word 'laugh'. Perplexity: 329.7235
#   > Evaluating word 'magi'. Perplexity: 350.3458
#   > Evaluating word 'walk'. Perplexity: 336.9220
#   > Evaluating word 'beard'. Perplexity: 343.1968
#   > Evaluating word 'game'. Perplexity: 340.7726
#   > Evaluating word 'milk'. Perplexity: 344.6409
#   > Evaluating word 'visit'. Perplexity: 338.2597
#   > Evaluating word 'naughty'. Perplexity: 340.1729
#   > Evaluating word 'nice'. Perplexity: 338.5656
#   > Evaluating word 'workshop'. Perplexity: 343.0608
#   > Evaluating word 'polar'. Perplexity: 345.7917
#   > Evaluating word 'wrapping'. Perplexity: 337.4275
#   > Evaluating word 'jump'. Perplexity: 342.3772
#   > Evaluating word 'greeting'. Perplexity: 335.0231
#   > Evaluating word 'chocolate'. Perplexity: 340.5276
#   >> Selected best word 'sing' with perplexity 315.3770
#
#   > Evaluating word 'dream'. Perplexity: 321.1328
#   > Evaluating word 'bake'. Perplexity: 320.7873
#   > Evaluating word 'angel'. Perplexity: 324.8347
#   > Evaluating word 'chimney'. Perplexity: 324.5104
#   > Evaluating word 'laugh'. Perplexity: 317.5803
#   > Evaluating word 'magi'. Perplexity: 345.0392
#   > Evaluating word 'walk'. Perplexity: 324.6523
#   > Evaluating word 'beard'. Perplexity: 337.7829
#   > Evaluating word 'game'. Perplexity: 328.6865
#   > Evaluating word 'milk'. Perplexity: 337.4020
#   > Evaluating word 'visit'. Perplexity: 329.8824
#   > Evaluating word 'naughty'. Perplexity: 330.5948
#   > Evaluating word 'nice'. Perplexity: 327.5831
#   > Evaluating word 'workshop'. Perplexity: 336.4076
#   > Evaluating word 'polar'. Perplexity: 339.4465
#   > Evaluating word 'wrapping'. Perplexity: 331.0301
#   > Evaluating word 'jump'. Perplexity: 325.3201
#   > Evaluating word 'greeting'. Perplexity: 326.2834
#   > Evaluating word 'chocolate'. Perplexity: 330.0740
#   >> Selected best word 'laugh' with perplexity 317.5803
#
#   > Evaluating word 'naughty'. Perplexity: 323.6223
#   > Evaluating word 'bake'. Perplexity: 327.5958
#   > Evaluating word 'nice'. Perplexity: 332.4533
#   > Evaluating word 'chocolate'. Perplexity: 329.7341
#   > Evaluating word 'chimney'. Perplexity: 324.1162
#   > Evaluating word 'game'. Perplexity: 323.9705
#   > Evaluating word 'angel'. Perplexity: 331.4514
#   > Evaluating word 'workshop'. Perplexity: 341.0842
#   > Evaluating word 'greeting'. Perplexity: 329.8743
#   > Evaluating word 'polar'. Perplexity: 343.3561
#   > Evaluating word 'magi'. Perplexity: 345.0132
#   > Evaluating word 'wrapping'. Perplexity: 330.9727
#   > Evaluating word 'milk'. Perplexity: 337.7001
#   > Evaluating word 'jump'. Perplexity: 319.1716
#   > Evaluating word 'dream'. Perplexity: 315.6631
#   > Evaluating word 'beard'. Perplexity: 340.0345
#   > Evaluating word 'visit'. Perplexity: 327.7563
#   > Evaluating word 'walk'. Perplexity: 323.1437
#   >> Selected best word 'dream' with perplexity 315.6631
#
#   > Evaluating word 'naughty'. Perplexity: 325.7095
#   > Evaluating word 'bake'. Perplexity: 321.8810
#   > Evaluating word 'nice'. Perplexity: 322.3542
#   > Evaluating word 'chocolate'. Perplexity: 322.5899
#   > Evaluating word 'chimney'. Perplexity: 321.4014
#   > Evaluating word 'game'. Perplexity: 324.3664
#   > Evaluating word 'angel'. Perplexity: 321.6007
#   > Evaluating word 'workshop'. Perplexity: 335.5945
#   > Evaluating word 'greeting'. Perplexity: 333.7182
#   > Evaluating word 'polar'. Perplexity: 337.9126
#   > Evaluating word 'magi'. Perplexity: 340.3275
#   > Evaluating word 'wrapping'. Perplexity: 331.1119
#   > Evaluating word 'milk'. Perplexity: 336.4267
#   > Evaluating word 'jump'. Perplexity: 323.3871
#   > Evaluating word 'beard'. Perplexity: 338.1992
#   > Evaluating word 'visit'. Perplexity: 320.1682
#   > Evaluating word 'walk'. Perplexity: 321.6231
#   >> Selected best word 'visit' with perplexity 320.1682
#
#   > Evaluating word 'naughty'. Perplexity: 326.5230
#   > Evaluating word 'bake'. Perplexity: 324.9897
#   > Evaluating word 'nice'. Perplexity: 326.3821
#   > Evaluating word 'chocolate'. Perplexity: 330.8286
#   > Evaluating word 'chimney'. Perplexity: 324.9581
#   > Evaluating word 'game'. Perplexity: 331.0988
#   > Evaluating word 'angel'. Perplexity: 325.7530
#   > Evaluating word 'workshop'. Perplexity: 333.4019
#   > Evaluating word 'greeting'. Perplexity: 328.1968
#   > Evaluating word 'polar'. Perplexity: 333.2839
#   > Evaluating word 'magi'. Perplexity: 341.5214
#   > Evaluating word 'wrapping'. Perplexity: 330.8671
#   > Evaluating word 'milk'. Perplexity: 337.1201
#   > Evaluating word 'jump'. Perplexity: 332.8789
#   > Evaluating word 'beard'. Perplexity: 341.5269
#   > Evaluating word 'walk'. Perplexity: 326.9901
#   >> Selected best word 'chimney' with perplexity 324.9581
#
#   > Evaluating word 'naughty'. Perplexity: 325.5557
#   > Evaluating word 'bake'. Perplexity: 326.7197
#   > Evaluating word 'nice'. Perplexity: 329.9871
#   > Evaluating word 'chocolate'. Perplexity: 330.0619
#   > Evaluating word 'chimney'. Perplexity: 314.1586
#   > Evaluating word 'game'. Perplexity: 336.3619
#   > Evaluating word 'angel'. Perplexity: 329.8687
#   > Evaluating word 'workshop'. Perplexity: 336.0350
#   > Evaluating word 'greeting'. Perplexity: 335.4067
#   > Evaluating word 'polar'. Perplexity: 339.3690
#   > Evaluating word 'magi'. Perplexity: 344.2870
#   > Evaluating word 'wrapping'. Perplexity: 336.1126
#   > Evaluating word 'milk'. Perplexity: 331.2457
#   > Evaluating word 'jump'. Perplexity: 328.0247
#   > Evaluating word 'beard'. Perplexity: 332.6471
#   > Evaluating word 'walk'. Perplexity: 327.8647
#   >> Selected best word 'chimney' with perplexity 314.1586
#
#   > Evaluating word 'naughty'. Perplexity: 318.0592
#   > Evaluating word 'bake'. Perplexity: 318.6958
#   > Evaluating word 'nice'. Perplexity: 322.9002
#   > Evaluating word 'chocolate'. Perplexity: 321.4204
#   > Evaluating word 'game'. Perplexity: 328.1570
#   > Evaluating word 'angel'. Perplexity: 320.2960
#   > Evaluating word 'workshop'. Perplexity: 327.3310
#   > Evaluating word 'greeting'. Perplexity: 324.5101
#   > Evaluating word 'polar'. Perplexity: 333.0064
#   > Evaluating word 'magi'. Perplexity: 333.2034
#   > Evaluating word 'wrapping'. Perplexity: 328.7201
#   > Evaluating word 'milk'. Perplexity: 322.3453
#   > Evaluating word 'jump'. Perplexity: 319.6020
#   > Evaluating word 'beard'. Perplexity: 321.8230
#   > Evaluating word 'walk'. Perplexity: 316.9347
#   >> Selected best word 'walk' with perplexity 316.9347
#
#   > Evaluating word 'naughty'. Perplexity: 323.4776
#   > Evaluating word 'bake'. Perplexity: 319.9459
#   > Evaluating word 'nice'. Perplexity: 325.1250
#   > Evaluating word 'game'. Perplexity: 330.5790
#   > Evaluating word 'angel'. Perplexity: 324.5675
#   > Evaluating word 'workshop'. Perplexity: 329.4589
#   > Evaluating word 'greeting'. Perplexity: 328.2450
#   > Evaluating word 'polar'. Perplexity: 331.5200
#   > Evaluating word 'magi'. Perplexity: 341.1329
#   > Evaluating word 'wrapping'. Perplexity: 329.1422
#   > Evaluating word 'milk'. Perplexity: 326.7082
#   > Evaluating word 'jump'. Perplexity: 322.0658
#   > Evaluating word 'beard'. Perplexity: 328.8113
#   > Evaluating word 'chocolate'. Perplexity: 324.7778
#   >> Selected best word 'bake' with perplexity 319.9459
#
#   > Evaluating word 'naughty'. Perplexity: 329.6845
#   > Evaluating word 'nice'. Perplexity: 329.5649
#   > Evaluating word 'angel'. Perplexity: 333.9334
#   > Evaluating word 'game'. Perplexity: 332.0902
#   > Evaluating word 'workshop'. Perplexity: 334.8182
#   > Evaluating word 'greeting'. Perplexity: 343.5596
#   > Evaluating word 'polar'. Perplexity: 336.7652
#   > Evaluating word 'magi'. Perplexity: 348.4129
#   > Evaluating word 'wrapping'. Perplexity: 330.4772
#   > Evaluating word 'milk'. Perplexity: 323.5233
#   > Evaluating word 'jump'. Perplexity: 326.7457
#   > Evaluating word 'beard'. Perplexity: 335.2689
#   > Evaluating word 'chocolate'. Perplexity: 321.9473
#   >> Selected best word 'chocolate' with perplexity 321.9473
#
#   > Evaluating word 'naughty'. Perplexity: 330.3140
#   > Evaluating word 'nice'. Perplexity: 331.2735
#   > Evaluating word 'angel'. Perplexity: 328.6569
#   > Evaluating word 'game'. Perplexity: 336.8269
#   > Evaluating word 'workshop'. Perplexity: 336.5185
#   > Evaluating word 'greeting'. Perplexity: 336.7784
#   > Evaluating word 'polar'. Perplexity: 333.0772
#   > Evaluating word 'magi'. Perplexity: 347.6522
#   > Evaluating word 'wrapping'. Perplexity: 327.6914
#   > Evaluating word 'milk'. Perplexity: 316.6593
#   > Evaluating word 'jump'. Perplexity: 331.6352
#   > Evaluating word 'beard'. Perplexity: 339.8297
#   >> Selected best word 'milk' with perplexity 316.6593
#
#   > Evaluating word 'naughty'. Perplexity: 323.5580
#   > Evaluating word 'nice'. Perplexity: 323.9728
#   > Evaluating word 'angel'. Perplexity: 334.9724
#   > Evaluating word 'game'. Perplexity: 327.7434
#   > Evaluating word 'workshop'. Perplexity: 340.1184
#   > Evaluating word 'greeting'. Perplexity: 334.8232
#   > Evaluating word 'polar'. Perplexity: 330.5804
#   > Evaluating word 'magi'. Perplexity: 340.8664
#   > Evaluating word 'wrapping'. Perplexity: 326.6687
#   > Evaluating word 'jump'. Perplexity: 324.7485
#   > Evaluating word 'beard'. Perplexity: 338.5082
#   >> Selected best word 'naughty' with perplexity 323.5580
#
#   > Evaluating word 'nice'. Perplexity: 312.1757
#   > Evaluating word 'angel'. Perplexity: 320.7203
#   > Evaluating word 'game'. Perplexity: 336.4899
#   > Evaluating word 'workshop'. Perplexity: 339.9104
#   > Evaluating word 'greeting'. Perplexity: 349.8843
#   > Evaluating word 'polar'. Perplexity: 332.3931
#   > Evaluating word 'magi'. Perplexity: 352.1674
#   > Evaluating word 'wrapping'. Perplexity: 340.8170
#   > Evaluating word 'jump'. Perplexity: 331.7379
#   > Evaluating word 'beard'. Perplexity: 344.5860
#   >> Selected best word 'nice' with perplexity 312.1757
#
#   > Evaluating word 'angel'. Perplexity: 313.9307
#   > Evaluating word 'game'. Perplexity: 319.1573
#   > Evaluating word 'workshop'. Perplexity: 321.3376
#   > Evaluating word 'greeting'. Perplexity: 327.3461
#   > Evaluating word 'polar'. Perplexity: 318.0046
#   > Evaluating word 'magi'. Perplexity: 334.5671
#   > Evaluating word 'wrapping'. Perplexity: 320.3629
#   > Evaluating word 'jump'. Perplexity: 318.3437
#   > Evaluating word 'beard'. Perplexity: 324.4320
#   >> Selected best word 'angel' with perplexity 313.9307
#
#   > Evaluating word 'game'. Perplexity: 327.3697
#   > Evaluating word 'workshop'. Perplexity: 323.8636
#   > Evaluating word 'greeting'. Perplexity: 322.5673
#   > Evaluating word 'polar'. Perplexity: 321.2402
#   > Evaluating word 'magi'. Perplexity: 330.2473
#   > Evaluating word 'wrapping'. Perplexity: 324.3854
#   > Evaluating word 'jump'. Perplexity: 325.6420
#   > Evaluating word 'beard'. Perplexity: 327.3477
#   >> Selected best word 'polar' with perplexity 321.2402
#
#   > Evaluating word 'game'. Perplexity: 333.0799
#   > Evaluating word 'workshop'. Perplexity: 333.8198
#   > Evaluating word 'greeting'. Perplexity: 338.5624
#   > Evaluating word 'magi'. Perplexity: 350.7421
#   > Evaluating word 'wrapping'. Perplexity: 337.0922
#   > Evaluating word 'jump'. Perplexity: 327.0445
#   > Evaluating word 'beard'. Perplexity: 334.9188
#   >> Selected best word 'jump' with perplexity 327.0445
#
#   > Evaluating word 'game'. Perplexity: 332.6342
#   > Evaluating word 'workshop'. Perplexity: 344.3817
#   > Evaluating word 'greeting'. Perplexity: 342.9217
#   > Evaluating word 'magi'. Perplexity: 357.2504
#   > Evaluating word 'wrapping'. Perplexity: 342.3993
#   > Evaluating word 'beard'. Perplexity: 342.0223
#   >> Selected best word 'game' with perplexity 332.6342
#
#   > Evaluating word 'workshop'. Perplexity: 346.6211
#   > Evaluating word 'greeting'. Perplexity: 348.7433
#   > Evaluating word 'magi'. Perplexity: 361.7501
#   > Evaluating word 'wrapping'. Perplexity: 344.3592
#   > Evaluating word 'beard'. Perplexity: 345.8664
#   >> Selected best word 'wrapping' with perplexity 344.3592
#
#   > Evaluating word 'beard'. Perplexity: 363.5356
#   > Evaluating word 'workshop'. Perplexity: 357.2090
#   > Evaluating word 'greeting'. Perplexity: 356.5248
#   > Evaluating word 'magi'. Perplexity: 369.1566
#   >> Selected best word 'greeting' with perplexity 356.5248
#
#   > Evaluating word 'beard'. Perplexity: 372.0974
#   > Evaluating word 'workshop'. Perplexity: 375.1170
#   > Evaluating word 'magi'. Perplexity: 380.1816
#   >> Selected best word 'beard' with perplexity 372.0974
#
#   > Evaluating word 'workshop'. Perplexity: 382.9683
#   > Evaluating word 'magi'. Perplexity: 396.6787
#   >> Selected best word 'workshop' with perplexity 382.9683
#
#   > Evaluating word 'workshop'. Perplexity: 373.8939
#   > Evaluating word 'magi'. Perplexity: 406.0733
#   >> Selected best word 'workshop' with perplexity 373.8939
#
#   > Evaluating word 'magi'. Perplexity: 394.8397
#   >> Selected best word 'magi' with perplexity 394.8397
#
#
# Final Submission DataFrame:
#    id                                               text
# 0   0  family fireplace scrooge reindeer mistletoe or...
# 1   1  reindeer give sleep scrooge mistletoe and the ...
# 2   2  carol yuletide beard ornament cheer holiday nu...
# 3   3  decorations gifts sing carol yuletide beard vi...
# 4   4  puzzle candle hope doll believe snowglobe pepp...
# 5   5  fireplace bow wreath reindeer have family driv...
#
# [SentencesGeneration] Final submission saved to /kaggle/working/submission.csv
#
# [Main] End-to-end process completed.
